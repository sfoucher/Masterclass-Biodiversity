# %% [markdown]
# # Export sub-frames
# We assume the following paths:
# * `/general_dataset/ground_truth/json/big_size/train_big_size_A_B_E_K_WH_WB.json` for training's sub-frames.
#
# * `/general_dataset/ground_truth/json/big_size/val_big_size_A_B_E_K_WH_WB.json` for validation's sub-frames (for using evaluation tools of mmdetection), with `object_only = False`.
#
# * `/general_dataset/ground_truth/json/big_size/test_big_size_A_B_E_K_WH_WB.json` for test's sub-frames (for using evaluation tools of mmdetection), with `object_only = False`.
#
# You can find theses subframes in `mmdetection/data/mammals`.

# %%
# !mkdir -p /general_dataset/sub_frames_500/train
# !mkdir -p /general_dataset/sub_frames_500/val
# !mkdir -p /general_dataset/sub_frames_500/test

# %%
from utils.Subframes import Subframes 
from utils.Subframes import subexport
# Out:
# /opt/conda/lib/python3.7/site-packages/mmcv/utils/registry.py:252: UserWarning: The old API of register_module(module, force=False) is deprecated and will be removed, please use the new API register_module(name=None, force=False, module=None) instead.
#   'The old API of register_module(module, force=False) '

# %%
# Fill in with your paths
images_folder = '/general_dataset/train' # < your specific path here >
annos_path = '/general_dataset/groundtruth/json/big_size/train_big_size_A_B_E_K_WH_WB.json' # '< your JSON annotations file path here >'
output_folder = '/general_dataset/sub_frames_500/train'
size= 500
# Export
json_dic = subexport(
        img_root = images_folder,
        ann_root = annos_path,
        width = size,
        height = size,
        output_folder = output_folder,
        strict = True,
        object_only = True
    )
# Out:
#
# --------------------------------------
# Sub-frames creation started...
# --------------------------------------
# Image [0   /928 ] done.
# Image [50  /928 ] done.
# Image [100 /928 ] done.
# Image [150 /928 ] done.
# Image [200 /928 ] done.
# Image [250 /928 ] done.

# %%
# Fill in with your paths
images_folder = '/general_dataset/val' # < your specific path here >
annos_path = '/general_dataset/groundtruth/json/big_size/val_big_size_A_B_E_K_WH_WB.json' # '< your JSON annotations file path here >'
output_folder = '/general_dataset/sub_frames_500/val'

# Export
json_dic = subexport(
        img_root = images_folder,
        ann_root = annos_path,
        width = size,
        height = size,
        output_folder = output_folder,
        strict = True,
        object_only = False
    )
# Out:
#
# --------------------------------------
# Sub-frames creation started...
# --------------------------------------
# Image [0   /111 ] done.
# Image [50  /111 ] done.
# Image [100 /111 ] done.
# --------------------------------------
# Sub-frames creation finished!
# --------------------------------------
# Elapsed time : 0:02:41
# --------------------------------------
#
# File 'coco_subframes.json' correctly saved at '/general_dataset/sub_frames/val'.

# %%
# Fill in with your paths
images_folder = '/general_dataset/test' # < your specific path here >
annos_path = '/general_dataset/groundtruth/json/big_size/test_big_size_A_B_E_K_WH_WB.json' # '< your JSON annotations file path here >'
output_folder = '/general_dataset/sub_frames_500/test'

# Export
json_dic = subexport(
        img_root = images_folder,
        ann_root = annos_path,
        width = size,
        height = size,
        output_folder = output_folder,
        strict = True,
        object_only = False
    )
# Out:
#
# --------------------------------------
# Sub-frames creation started...
# --------------------------------------
# Image [0   /258 ] done.
# Image [50  /258 ] done.
# Image [100 /258 ] done.
# Image [150 /258 ] done.
# Image [200 /258 ] done.
# Image [250 /258 ] done.
# --------------------------------------
# Sub-frames creation finished!
# --------------------------------------
# Elapsed time : 0:07:33
# --------------------------------------
#
# File 'coco_subframes.json' correctly saved at '/general_dataset/sub_frames/test'.
